# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# %%
# Read School and Student Data File and store into Pandas DataFrames
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# %%
school_data_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_data_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data_df, school_data_df, how="left", on=["school_name", "school_name"])

# %%
#Separate the columns in the dataframe. I really wanted to be able to 
#visualize my data in an organized way
#renamed_data_df = school_data_complete.rename(columns={
#"school_name": "School Name",
#"type": "School Type",
#"budget": "Total Budget",
#"reading_score": "Reading Score",
#"math_score": "Math Score",
#"student_name": "Student Name",
#"gender": "Gender",
#"grade": "Grade",
#"size": "Size"})
#renamed_data_df

# %%
#1a) Create a df listing all of the unique schools
school = ["school_name"]
school
school_data_df.loc[:, school]
# Out:
#               school_name
# 0       Huang High School
# 1    Figueroa High School
# 2     Shelton High School
# 3   Hernandez High School
# 4     Griffin High School
# 5      Wilson High School
# 6     Cabrera High School
# 7      Bailey High School
# 8      Holden High School
# 9        Pena High School
# 10     Wright High School
# 11  Rodriguez High School
# 12    Johnson High School
# 13       Ford High School
# 14     Thomas High School

# %%
#1b) Count each school in the newly created dataframe
total_schools = school_data_df["school_name"].count()
total_schools
# Out:
# 15

# %%
#2a) Create a df listing all of the unique student names
students = ["student_name"]
students
student_data_df.loc[:, students]
# Out:
#             student_name
# 0           Paul Bradley
# 1           Victor Smith
# 2        Kevin Rodriguez
# 3      Dr. Richard Scott
# 4             Bonnie Ray
# ...                  ...
# 39165       Donna Howard
# 39166          Dawn Bell
# 39167     Rebecca Tanner
# 39168       Desiree Kidd
# 39169    Carolyn Jackson
#
# [39170 rows x 1 columns]

# %%
#2b) Total number of students
total_students = school_data_df["size"].sum()
total_students
# Out:
# 39170

# %%
#3a) Create a df for the budgets of each school
budgets = ["budget"]
budgets
school_data_df.loc[:, budgets]
# Out:
#      budget
# 0   1910635
# 1   1884411
# 2   1056600
# 3   3022020
# 4    917500
# 5   1319574
# 6   1081356
# 7   3124928
# 8    248087
# 9    585858
# 10  1049400
# 11  2547363
# 12  3094650
# 13  1763916
# 14  1043130

# %%
#3b) Calculate total school budget
total_budget = school_data_df["budget"].sum()
total_budget
# Out:
# 24649428

# %%
#4a) Create a df for all of the math scores
math_scores = ["math_score"]
math_scores
student_data_df.loc[:, math_scores]
# Out:
#        math_score
# 0              79
# 1              61
# 2              60
# 3              58
# 4              84
# ...           ...
# 39165          90
# 39166          70
# 39167          84
# 39168          90
# 39169          75
#
# [39170 rows x 1 columns]

# %%
#4b) Calculate the average math score
math_avg = student_data_df["math_score"].mean()
math_avg
# Out:
# 78.98537145774827

# %%
#5a) Created a df for all of the reading scores
reading_scores = ["reading_score"]
reading_scores
student_data_df.loc[:, reading_scores]
# Out:
#        reading_score
# 0                 66
# 1                 94
# 2                 90
# 3                 67
# 4                 97
# ...              ...
# 39165             99
# 39166             95
# 39167             73
# 39168             99
# 39169             95
#
# [39170 rows x 1 columns]

# %%
#5b) Average readings score
reading_avg = student_data_df["reading_score"].mean()
reading_avg
# Out:
# 81.87784018381414

# %%
#6a) Create a dataframe of math scores >= 70 (True/False)
math_pass = ["math_score"]
math_pass
student_data_df.loc[:, math_scores] >=70
# Out:
#        math_score
# 0            True
# 1           False
# 2           False
# 3           False
# 4            True
# ...           ...
# 39165        True
# 39166        True
# 39167        True
# 39168        True
# 39169        True
#
# [39170 rows x 1 columns]

# %%
#6b) Passing Math (The percentage of students that passed math.)
math_pass_tot = student_data_df["math_score"].loc[student_data_df["math_score"] >=70].count() 
math_pass_rate = (math_pass_tot/total_students)*100
math_pass_rate
# Out:
# 74.9808526933878

# %%
#7a) Create a dataframe of math scores >= 70 (True/False)
math_pass = ["math_score"]
math_pass
student_data_df.loc[:, math_scores] >=70
# Out:
#        math_score
# 0            True
# 1           False
# 2           False
# 3           False
# 4            True
# ...           ...
# 39165        True
# 39166        True
# 39167        True
# 39168        True
# 39169        True
#
# [39170 rows x 1 columns]

# %%
#7b) Passing Reading (The percentage of students that passed reading.)
read_pass_tot = student_data_df["reading_score"].loc[student_data_df["reading_score"] >=70].count()
read_pass_rate = (read_pass_tot/total_students)*100
read_pass_rate
# Out:
# 85.80546336482001

# %%
#8a) Create a dataframe of reading scores >= 70 (True/False)
math_read_pass = ["math_score","reading_score"]
math_read_pass
student_data_df.loc([:, reading_scores] >=70) & (student_data_df[:, math_scores] >=70) ])
# Out:
#   File "<ipython-input-22-e93fb865ab01>", line 4
#     student_data_df.loc([:, reading_scores] >=70) & (student_data_df[:, math_scores] >=70) ])
#                          ^
# SyntaxError: invalid syntax

# %%
#8b) Overall Passing (The percentage of students that passed math and reading.)
math_read_pass_rate = student_data_df.loc[(student_data_df["reading_score"] >=70) & (student_data_df["math_score"] >=70),:].mean()
math_read_pass_rate
# Out:
# Student ID       19586.574663
# reading_score       84.457028
# math_score          84.455892
# dtype: float64

# %%
#9a) Remove unnecessary columns
remove_row_df = school_data_complete.drop(columns=['Student ID', 
                            'student_name', 
                            'gender', 
                            'grade', 'School ID'])
remove_row_df
# Out:
#               school_name  reading_score  math_score      type  size   budget
# 0       Huang High School             66          79  District  2917  1910635
# 1       Huang High School             94          61  District  2917  1910635
# 2       Huang High School             90          60  District  2917  1910635
# 3       Huang High School             67          58  District  2917  1910635
# 4       Huang High School             97          84  District  2917  1910635
# ...                   ...            ...         ...       ...   ...      ...
# 39165  Thomas High School             99          90   Charter  1635  1043130
# 39166  Thomas High School             95          70   Charter  1635  1043130
# 39167  Thomas High School             73          84   Charter  1635  1043130
# 39168  Thomas High School             99          90   Charter  1635  1043130
# 39169  Thomas High School             95          75   Charter  1635  1043130
#
# [39170 rows x 6 columns]

# %%
#9b) Add necessary columns
add_row_df = school_data_complete.add(columns=['% Passing Math', 
                                               '% Passing Reading', 
                                               '% Overall Passing'])))
add_row_df
# Out:
#   File "<ipython-input-32-6946e36910ba>", line 2
#     add_row_df = school_data_complete.(add(columns=['% Passing Math',
#                                       ^
# SyntaxError: invalid syntax

# %%
#9a) Rename headers
renamed_data_df = school_data_complete.rename(columns={
"school_name": "School Name",
"budget": "Total Budget",
"math_score": "Average Math Score",
"reading_score": "Average Reading Score"})
#"math_pass": "% Passing Math"
#"read_pass": "% Passing Reading"
#"math_read_pass": "% Overall Passing"
renamed_data_df
# Out:
#        Student ID       student_name gender grade         School Name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        Average Reading Score  Average Math Score  School ID      type  size  \
# 0                         66                  79          0  District  2917
# 1                         94                  61          0  District  2917
# 2                         90                  60          0  District  2917
# 3                         67                  58          0  District  2917
# 4                         97                  84          0  District  2917
# ...                      ...                 ...        ...       ...   ...
# 39165                     99                  90         14   Charter  1635
# 39166                     95                  70         14   Charter  1635
# 39167                     73                  84         14   Charter  1635
# 39168                     99                  90         14   Charter  1635
# 39169                     95                  75         14   Charter  1635
#
#        Total Budget
# 0           1910635
# 1           1910635
# 2           1910635
# 3           1910635
# 4           1910635
# ...             ...
# 39165       1043130
# 39166       1043130
# 39167       1043130
# 39168       1043130
# 39169       1043130
#
# [39170 rows x 11 columns]

# %%
#9c) Create summary table
summary_table_df = school_data_complete.groupby("school_name")

renamed_data_df = pd.DataFrame(
{"School Name": schools,
"School Type": school_type,
"Total Students": total_budget,
"Total School Budget"
"Per Student Budget": reading_avg,
"Average Math Score"
"Average Reading Score": math_avg,
"% Passing Math"
"% passing Reading"
"% Overall Passing":})
renamed_data_df

# %%
#Part 2 - School Summary
#Create an overview table that summarizes key metrics about 
#each school, including:

# %%
#Show School Data
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %%
#1) Create table with school names
unique_school = ["school_name"]
unique_school
school_data_complete.loc[:, school]
# Out:
#               school_name
# 0       Huang High School
# 1       Huang High School
# 2       Huang High School
# 3       Huang High School
# 4       Huang High School
# ...                   ...
# 39165  Thomas High School
# 39166  Thomas High School
# 39167  Thomas High School
# 39168  Thomas High School
# 39169  Thomas High School
#
# [39170 rows x 1 columns]

# %%
#2) Create table with school type
school_type = ["type"]
school_type
school_data_df.loc[:, type]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-5390598c6606> in <module>
#       3 school_type = ["type"]
#       4 school_type
# ----> 5 school_data_df.loc[:, type]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3474
#    3475         if axis == 1:
# -> 3476             return self[key]
#    3477
#    3478         index = self.index
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2887         # Do we have a (boolean) DataFrame?
#    2888         if isinstance(key, DataFrame):
# -> 2889             return self.where(key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8994         other = com.apply_if_callable(other, self)
#    8995         return self._where(
# -> 8996             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    8997         )
#    8998
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8755                 for dt in cond.dtypes:
#    8756                     if not is_bool_dtype(dt):
# -> 8757                         raise ValueError(msg.format(dtype=dt))
#    8758         else:
#    8759             # GH#21947 we have an empty DataFrame/Series, could be object-dtype
#
# ValueError: Boolean array expected for the condition, not int64

# %%
#3a) Create table with total students
total_students_df = ["size"]
total_students_df
complete_data_df.loc[school]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-507e9c2ddcc4> in <module>
#       2 total_students_df = ["size"]
#       3 total_students_df
# ----> 4 complete_data_df.loc[school]
#
# NameError: name 'complete_data_df' is not defined

# %%
#total_students_df.loc[total_students]
unique_school = ["school_name"]
unique_school
school_data_df.loc[:, school]

# %%
#3b)
students = ["student_name"]
students
student_data_df.loc[:, students]
# Out:
#             student_name
# 0           Paul Bradley
# 1           Victor Smith
# 2        Kevin Rodriguez
# 3      Dr. Richard Scott
# 4             Bonnie Ray
# ...                  ...
# 39165       Donna Howard
# 39166          Dawn Bell
# 39167     Rebecca Tanner
# 39168       Desiree Kidd
# 39169    Carolyn Jackson
#
# [39170 rows x 1 columns]
